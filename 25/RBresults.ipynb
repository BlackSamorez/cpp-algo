# %%
import numpy as np
import pandas as pd

# %%
FIND = pd.read_csv("FIND.txt", header=0, sep=';')
INSERT = pd.read_csv("INSERT.txt", header=0, sep=';')
ERASE = pd.read_csv("ERASE.txt", header=0, sep=';')
result = pd.concat([INSERT, ERASE, FIND], axis=1, sort=False)

# %%
result.plot()
print("Microseconds for 10000 operations with 2^x tree size")
# Out:
# Microseconds for 10000 operations with 2^x tree size
